# %% [markdown]
# # Problem Statement::

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ## DATA::

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# # SOLUTION::
# ###  METHOD-1 ----> Without using or considering the Block design(RANDOMIZED BLOCK DESIGN APPROACH) while calculating the Error sum of Square(SSE) our result is so showmn below:

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ![2.1.png](attachment:2.1.png)

# %% [markdown]
# # So here we can see without RBD approach gives us the result that ----> WE SHOULD ACCEPT THE NULL HYPOTHESIS (ALL MEANS ARE EQUAL) .

# %% [markdown]
# # METHOD-2 :: Now considering the RBD approach which helps removing the nuisance or extraneous factor while calculating the SSE(Error Sum Of Square).

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# ![8.png](attachment:8.png)

# %% [markdown]
# ![9.png](attachment:9.png)

# %% [markdown]
# # Contradictory to the previous method this RBD approach removes the extraneous/nuisance factors and gives a different inference ----> WE SHOULD REJECT THE NULL HYPOTHESIS (ALL MEANS ARE EQUAL).

# %% [markdown]
# ![10.png](attachment:10.png)
